# %%
import os
import torch
from PIL import Image
import torchvision.transforms as T
import matplotlib.pyplot as plt
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

############################
# 모델 구조 정의 (학습시 사용한 것과 동일)
############################

class GatedConv2d(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, activation=torch.nn.ReLU()):
        super(GatedConv2d, self).__init__()
        self.feature_conv = torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.mask_conv = torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.sigmoid = torch.nn.Sigmoid()
        self.activation = activation

    def forward(self, x):
        f = self.feature_conv(x)
        m = self.mask_conv(x)
        gated = self.sigmoid(m)
        if self.activation is not None:
            f = self.activation(f)
        return f * gated

class GatedDeconv2d(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=4, stride=2, padding=1, activation=torch.nn.ReLU()):
        super(GatedDeconv2d, self).__init__()
        self.feature_deconv = torch.nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding)
        self.mask_deconv = torch.nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding)
        self.sigmoid = torch.nn.Sigmoid()
        self.activation = activation

    def forward(self, x):
        f = self.feature_deconv(x)
        m = self.mask_deconv(x)
        gated = self.sigmoid(m)
        if self.activation is not None:
            f = self.activation(f)
        return f * gated

class ContextualAttention(torch.nn.Module):
    def __init__(self, kernel_size=3, stride=1, dilation=1):
        super(ContextualAttention, self).__init__()
        self.conv = torch.nn.Conv2d(512, 512, kernel_size, stride, dilation, bias=False)
        self.softmax = torch.nn.Softmax(dim=-1)

    def forward(self, x):
        B,C,H,W = x.size()
        query = x.view(B,C,-1)
        key = x.view(B,C,-1)
        value = x.view(B,C,-1)
        attn = torch.bmm(query.permute(0,2,1), key)
        attn = self.softmax(attn)
        out = torch.bmm(attn, value.permute(0,2,1))
        out = out.permute(0,2,1).view(B,C,H,W)
        out = self.conv(out)
        return out

class Stage1Generator(torch.nn.Module):
    def __init__(self):
        super(Stage1Generator, self).__init__()
        self.encoder = torch.nn.Sequential(
            GatedConv2d(4, 64, 4, 2, 1),
            GatedConv2d(64, 128, 4, 2, 1),
            GatedConv2d(128, 256, 4, 2, 1),
            GatedConv2d(256, 512, 4, 2, 1)
        )
        self.decoder = torch.nn.Sequential(
            GatedDeconv2d(512, 256, 4, 2, 1),
            GatedDeconv2d(256, 128, 4, 2, 1),
            GatedDeconv2d(128, 64, 4, 2, 1),
            GatedDeconv2d(64, 64, 4, 2, 1, activation=torch.nn.ReLU()),
            torch.nn.Conv2d(64, 3, 3, 1, 1),
            torch.nn.Sigmoid()
        )

    def forward(self, x, mask):
        inp = torch.cat((x, mask), dim=1)
        feat = self.encoder(inp)
        out = self.decoder(feat)
        return out

class Stage2Generator(torch.nn.Module):
    def __init__(self):
        super(Stage2Generator, self).__init__()
        self.encoder = torch.nn.Sequential(
            GatedConv2d(7, 64, 4, 2, 1),
            GatedConv2d(64, 128, 4, 2, 1),
            GatedConv2d(128, 256, 4, 2, 1),
            GatedConv2d(256, 512, 4, 2, 1)
        )
        self.contextual_attention = ContextualAttention()
        self.decoder = torch.nn.Sequential(
            GatedDeconv2d(512, 256, 4, 2, 1),
            GatedDeconv2d(256, 128, 4, 2, 1),
            GatedDeconv2d(128, 64, 4, 2, 1),
            GatedDeconv2d(64, 64, 4, 2, 1, activation=torch.nn.ReLU()),
            torch.nn.Conv2d(64, 3, 3, 1, 1),
            torch.nn.Sigmoid()
        )

    def forward(self, coarse_out, inp, mask):
        fin_inp = torch.cat((coarse_out, inp, mask), dim=1)
        feat = self.encoder(fin_inp)
        feat = self.contextual_attention(feat)
        out = self.decoder(feat)
        return out

# 최적 모델 가중치 경로
best_coarse_path = "best_coarse_generator_epoch5.pth"
best_fine_path = "best_fine_generator_epoch5.pth"


# 테스트 이미지(손상된 컬러 이미지) 폴더
test_input_dir = "../02_color/data/output_grayTocol_2024123101"
test_mask_dir = "../data/output_01_mask"
output_dir = "data/output_colToper_2024123101"

os.makedirs(output_dir, exist_ok=True)

coarse_generator = Stage1Generator().to(device)
fine_generator = Stage2Generator().to(device)

coarse_generator.load_state_dict(torch.load(best_coarse_path, map_location=device, weights_only=True))
fine_generator.load_state_dict(torch.load(best_fine_path, map_location=device, weights_only=True))

coarse_generator.eval()
fine_generator.eval()

transform = T.Compose([
    T.Resize((512,512)),
    T.ToTensor()
])

test_files = [f for f in os.listdir(test_input_dir) if f.lower().endswith(('.png','.jpg','.jpeg'))]

with torch.no_grad():
    for filename in test_files:
        input_path = os.path.join(test_input_dir, filename)
        mask_path = os.path.join(test_mask_dir, filename)

        if not os.path.exists(mask_path):
            print(f"{mask_path}가 존재하지 않습니다. 스킵합니다.")
            continue

        inp_img = Image.open(input_path).convert("RGB")
        mask_img = Image.open(mask_path).convert("L")

        inp_tensor = transform(inp_img).unsqueeze(0).to(device)   # (1,3,H,W)
        mask_tensor = transform(mask_img).unsqueeze(0).to(device) # (1,1,H,W)

        # 손상 영역 0 처리
        mask_broadcast = mask_tensor.expand_as(inp_tensor)
        damaged_inp = inp_tensor * (1 - mask_broadcast)

        # 복원
        coarse_out = coarse_generator(damaged_inp, mask_tensor)
        fine_out = fine_generator(coarse_out, damaged_inp, mask_tensor)

        # 여기서 복원된 부분(fine_out)을 마스크가 1인 영역에만 적용
        # final_result = original_damaged_image * (1 - mask) + fine_out * mask
        final_result = inp_tensor * (1 - mask_broadcast) + fine_out * mask_broadcast

        # 결과 텐서를 이미지로 변환
        final_result_pil = T.ToPILImage()(final_result.squeeze(0).cpu())

        save_path = os.path.join(output_dir, filename)
        final_result_pil.save(save_path)
        print(f"{filename} 복원 완료(마스크 영역만 덮어쓰기) -> {save_path}")
# Out:
# TEST_000.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_000.png
# TEST_001.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_001.png
# TEST_002.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_002.png
# TEST_003.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_003.png
# TEST_004.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_004.png
# TEST_005.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_005.png
# TEST_006.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_006.png
# TEST_007.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_007.png
# TEST_008.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_008.png
# TEST_009.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_009.png
# TEST_010.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_010.png
# TEST_011.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_011.png
# TEST_012.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_012.png
# TEST_013.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_013.png
# TEST_014.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_014.png
# TEST_015.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_015.png
# TEST_016.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_016.png
# TEST_017.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_017.png
# TEST_018.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_018.png
# TEST_019.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_019.png
# TEST_020.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_020.png
# TEST_021.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_021.png
# TEST_022.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_022.png
# TEST_023.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_023.png
# TEST_024.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_024.png
# TEST_025.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_025.png
# TEST_026.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_026.png
# TEST_027.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_027.png
# TEST_028.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_028.png
# TEST_029.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_029.png
# TEST_030.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_030.png
# TEST_031.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_031.png
# TEST_032.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_032.png
# TEST_033.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_033.png
# TEST_034.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_034.png
# TEST_035.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_035.png
# TEST_036.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_036.png
# TEST_037.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_037.png
# TEST_038.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_038.png
# TEST_039.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_039.png
# TEST_040.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_040.png
# TEST_041.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_041.png
# TEST_042.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_042.png
# TEST_043.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_043.png
# TEST_044.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_044.png
# TEST_045.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_045.png
# TEST_046.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_046.png
# TEST_047.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_047.png
# TEST_048.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_048.png
# TEST_049.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_049.png
# TEST_050.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_050.png
# TEST_051.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_051.png
# TEST_052.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_052.png
# TEST_053.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_053.png
# TEST_054.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_054.png
# TEST_055.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_055.png
# TEST_056.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_056.png
# TEST_057.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_057.png
# TEST_058.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_058.png
# TEST_059.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_059.png
# TEST_060.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_060.png
# TEST_061.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_061.png
# TEST_062.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_062.png
# TEST_063.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_063.png
# TEST_064.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_064.png
# TEST_065.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_065.png
# TEST_066.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_066.png
# TEST_067.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_067.png
# TEST_068.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_068.png
# TEST_069.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_069.png
# TEST_070.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_070.png
# TEST_071.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_071.png
# TEST_072.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_072.png
# TEST_073.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_073.png
# TEST_074.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_074.png
# TEST_075.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_075.png
# TEST_076.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_076.png
# TEST_077.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_077.png
# TEST_078.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_078.png
# TEST_079.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_079.png
# TEST_080.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_080.png
# TEST_081.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_081.png
# TEST_082.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_082.png
# TEST_083.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_083.png
# TEST_084.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_084.png
# TEST_085.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_085.png
# TEST_086.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_086.png
# TEST_087.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_087.png
# TEST_088.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_088.png
# TEST_089.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_089.png
# TEST_090.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_090.png
# TEST_091.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_091.png
# TEST_092.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_092.png
# TEST_093.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_093.png
# TEST_094.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_094.png
# TEST_095.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_095.png
# TEST_096.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_096.png
# TEST_097.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_097.png
# TEST_098.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_098.png
# TEST_099.png 복원 완료(마스크 영역만 덮어쓰기) -> data/output_colToper_2024123101\TEST_099.png
